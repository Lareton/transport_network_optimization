# %%
# !git clone https://github.com/Lareton/transport_network_optimization.git
# !pip install tqdm
# !pip install scanf

# !echo "deb http://downloads.skewed.de/apt focal main" >> /etc/apt/sources.list
# !apt-key adv --keyserver keyserver.ubuntu.com --recv-key 612DEFB798507F25
# !apt-get update
# !apt-get install python3-graph-tool #python3-matplotlib python3-cair

# !git clone https://github.com/niquepolice/bigchallenges.git

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tqdm import tqdm

from transport_network_optimization.transport_problem import DualOracle, OptimParams
from transport_network_optimization.acrcd import ACRCDOracleStacker, ACRCD_star
import numpy as np

from transport_network_optimization.transport_problem import HyperParams, OptimParams
import numpy as np
import scipy
import matplotlib.pyplot as plt
from pathlib import Path
from transport_network_optimization.read_data import get_network_df, get_corrs, get_full_df
from numba.core import types
import numba

from numba import njit
from graph_tool.topology import shortest_distance
import pandas as pd
import networkx as nx
import graph_tool as gt
from graph_tool.topology import shortest_distance
import numpy as np
import typing

import numba
from numba.core import types

# %%
net_df = get_network_df(Path('transport_network_optimization/SiouxFalls') / 'SiouxFalls_net.tntp')
corrs = get_corrs(Path('transport_network_optimization/SiouxFalls') / 'SiouxFalls_trips.tntp')
people_count = corrs.sum()
corrs = corrs / people_count
net_df.capacity /= people_count
graph = gt.Graph(net_df.values, eprops=[('capacity', 'double'), ('fft', 'double')])

# %%
l = np.sum(corrs, axis=1)
w = np.sum(corrs, axis=0)

zones_num = len(l)
sources = np.arange(zones_num)
targets = np.arange(zones_num)

params = HyperParams(gamma=10, mu_pow=0.25, rho=0.15)

# %%
def test_transport_problem(graph, net_df, l, w, params, sources, targets):
    dual_oracle = DualOracle(
        graph, l, w, params
    )
    oracle_stacker = ACRCDOracleStacker(
        dual_oracle,
        graph,
        sources,
        targets
    )
    return ACRCD_star(oracle_stacker, *oracle_stacker.get_init_vars_block(), 100)

# %%
t_calls, la_mu_calls, history, dgap_log, la_mu_grad_norms, t_grad_norms, x1_list, x2_list, *l_ = test_transport_problem(graph, net_df, l, w, params, sources, targets)
# Out:
# 1
#   0%|          | 0/100 [00:00<?, ?it/s]
# z2.shape=(48,)
# y2.shape=(48,)
#   0%|          | 0/100 [00:00<?, ?it/s]
#  11%|█         | 11/100 [00:00<00:01, 74.57it/s]
#   1%|          | 1/100 [00:00<00:17,  5.55it/s]
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852409254
# grad dF dmu:  0.11333220509656691
# sampled 1.7642524042858032e-05
# 54.13746196132573
# 54.13746196132573
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852409254
# grad dF dmu:  0.11333220509656691
# sampled 8.821262021429016e-06
# 54.13746196132573
# 54.13746196132573
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852409254
# grad dF dmu:  0.11333220509656691
# sampled 4.410631010714508e-06
# 54.13746196132573
# 54.13746196132573
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852409254
# grad dF dmu:  0.11333220509656691
# sampled 2.205315505357254e-06
# 54.13746196132573
# 54.13746196132573
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852409254
# grad dF dmu:  0.11333220509656691
# sampled 1.102657752678627e-06
# 54.13746196132573
# 54.13746196132573
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852409254
# grad dF dmu:  0.11333220509656691
# sampled 5.513288763393135e-07
# 54.13746196132573
# 54.13746196132573
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852409254
# grad dF dmu:  0.11333220509656691
# sampled 2.7566443816965676e-07
# 54.13746196132573
# 54.13746196132573
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852409254
# grad dF dmu:  0.11333220509656691
# sampled 1.3783221908482838e-07
# 54.13746196132573
# 54.13746196132573
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852409254
# grad dF dmu:  0.11333220509656691
# sampled 6.891610954241419e-08
# 54.13746196132573
# 54.13746196132573
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852409254
# grad dF dmu:  0.11333220509656691
# sampled 3.4458054771207094e-08
# 54.13746196132573
# 54.13746196132573
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852409254
# grad dF dmu:  0.11333220509656691
# sampled 1.7229027385603547e-08
# 54.13746196132573
# 54.13746196132573
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852409254
# grad dF dmu:  0.11333220509656691
# sampled 8.614513692801774e-09
# 54.13746196132573
# 54.13746196132573
# z2.shape=(48,)
# y2.shape=(48,)
# /content/transport_network_optimization/transport_problem.py:81: RuntimeWarning: invalid value encountered in power
#   return self.f_bar * ((optim_params.t - self.t_bar) ** self.params.mu_pow) / (
#
#   0%|          | 0/100 [00:00<?, ?it/s]
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326853235986
# grad dF dmu:  0.11333220510468242
# sampled 1.7639594822289064e-08
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326853235986
# grad dF dmu:  0.11333220510468242
# sampled
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852657275
# grad dF dmu:  0.11333220509900155
# sampled 1.859601001659943e-89
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852657275
# grad dF dmu:  0.11333220509900155
# sampled 9.298005008299714e-90
# nan
# nan
# sampled_gradient_x.shape=(76,)
#  78%|███████▊  | 78/100 [00:01<00:00, 76.23it/s]
# grad dF dla:  0.11352326852657275
# grad dF dmu:  0.11333220509900155
# sampled 4.649002504149857e-90
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852657275
# grad dF dmu:  0.11333220509900155
# sampled 2.3245012520749286e-90
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852657275
# grad dF dmu:  0.11333220509900155
# sampled 1.1622506260374643e-90
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852657275
# grad dF dmu:  0.11333220509900155
# sampled 5.811253130187321e-91
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852657275
# grad dF dmu:  0.11333220509900155
# sampled 2.9056265650936607e-91
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852657275
# grad dF dmu:  0.11333220509900155
# sampled 1.4528132825468304e-91
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852657275
# grad dF dmu:  0.11333220509900155
# sampled 7.264066412734152e-92
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852657275
# grad dF dmu:  0.11333220509900155
# sampled 3.632033206367076e-92
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852657275
# grad dF dmu:  0.11333220509900155
# sampled 1.816016603183538e-92
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852657275
# grad dF dmu:  0.11333220509900155
# sampled 9.08008301591769e-93
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852657275
# grad dF dmu:  0.11333220509900155
# sampled 4.540041507958845e-93
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852657275
# grad dF dmu:  0.11333220509900155
# sampled 2.2700207539794224e-93
# nan
# nan
# sampled_gradient_x.shape=(76,)
#  87%|████████▋ | 87/100 [00:01<00:00, 78.89it/s]
# grad dF dla:  0.11352326852657275
# grad dF dmu:  0.11333220509900155
# sampled 1.1350103769897112e-93
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852657275
# grad dF dmu:  0.11333220509900155
# sampled 5.675051884948556e-94
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852657275
# grad dF dmu:  0.11333220509900155
# sampled 2.837525942474278e-94
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852657275
# grad dF dmu:  0.11333220509900155
# sampled 1.418762971237139e-94
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852657275
# grad dF dmu:  0.11333220509900155
# sampled 7.093814856185695e-95
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852657275
# grad dF dmu:  0.11333220509900155
#  95%|█████████▌| 95/100 [00:01<00:00, 77.86it/s]
# sampled 3.5469074280928475e-95
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852657275
# grad dF dmu:  0.11333220509900155
# sampled 1.7734537140464238e-95
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852657275
# grad dF dmu:  0.11333220509900155
# sampled 8.867268570232119e-96
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852657275
# grad dF dmu:  0.11333220509900155
# sampled 4.4336342851160594e-96
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852657275
# grad dF dmu:  0.11333220509900155
# sampled 2.2168171425580297e-96
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852657275
# grad dF dmu:  0.11333220509900155
# sampled 1.1084085712790149e-96
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852657275
# grad dF dmu:  0.11333220509900155
# 100%|██████████| 100/100 [00:01<00:00, 68.73it/s]
#   4%|▍         | 4/100 [00:04<02:03,  1.29s/it]
# sampled 5.542042856395074e-97
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852657275
# grad dF dmu:  0.11333220509900155
# sampled 2.771021428197537e-97
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852657275
# grad dF dmu:  0.11333220509900155
# sampled 1.3855107140987686e-97
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852657275
# grad dF dmu:  0.11333220509900155
# sampled 6.927553570493843e-98
# nan
# nan
# z2.shape=(48,)
# y2.shape=(48,)
#   0%|          | 0/100 [00:00<?, ?it/s]
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852574601
# grad dF dmu:  0.11333220509818999
# sampled 6.927553570020407e-98
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852574601
# grad dF dmu:  0.11333220509818999
# sampled 3.4637767850102036e-98
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852574601
# grad dF dmu:  0.11333220509818999
# sampled 1.7318883925051018e-98
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852574601
# grad dF dmu:  0.11333220509818999
# sampled 8.659441962525509e-99
# nan
# nan
# sampled_gradient_x.shape=(76,)
#  10%|█         | 10/100 [00:00<00:00, 97.71it/s]
# grad dF dla:  0.11352326852574601
# grad dF dmu:  0.11333220509818999
# sampled 4.3297209812627546e-99
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852574601
# grad dF dmu:  0.11333220509818999
# sampled 2.1648604906313773e-99
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852574601
# grad dF dmu:  0.11333220509818999
# sampled 1.0824302453156886e-99
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852574601
# grad dF dmu:  0.11333220509818999
# sampled 5.412151226578443e-100
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852574601
# grad dF dmu:  0.11333220509818999
# sampled 2.7060756132892216e-100
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852574601
# grad dF dmu:  0.11333220509818999
# sampled 1.3530378066446108e-100
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852574601
# grad dF dmu:  0.11333220509818999
# sampled 6.765189033223054e-101
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852574601
# grad dF dmu:  0.11333220509818999
# sampled 3.382594516611527e-101
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852574601
# grad dF dmu:  0.11333220509818999
# sampled 1.6912972583057635e-101
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852574601
# grad dF dmu:  0.11333220509818999
# sampled 8.456486291528818e-102
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852574601
# grad dF dmu:  0.11333220509818999
# sampled 4.228243145764409e-102
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852574601
# grad dF dmu:  0.11333220509818999
# ...
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852446834
# grad dF dmu:  0.11333220509693577
# sampled 3.371497898401978e-306
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852446834
# grad dF dmu:  0.11333220509693577
# sampled 1.685748949200989e-306
# nan
# nan
#  11%|█         | 11/100 [00:13<01:52,  1.27s/it]
# z2.shape=(48,)
# y2.shape=(48,)
#   0%|          | 0/100 [00:00<?, ?it/s]
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 1.685748949192933e-306
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 8.428744745964665e-307
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 4.214372372982332e-307
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 2.107186186491166e-307
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 1.053593093245583e-307
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 5.267965466227915e-308
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 2.6339827331139577e-308
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 1.316991366556979e-308
# nan
# nan
# sampled_gradient_x.shape=(76,)
#   9%|▉         | 9/100 [00:00<00:01, 87.69it/s]
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 6.584956832784894e-309
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 3.292478416392447e-309
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 1.64623920819622e-309
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 8.2311960409811e-310
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
#  18%|█▊        | 18/100 [00:00<00:01, 77.12it/s]
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
#  27%|██▋       | 27/100 [00:00<00:00, 79.48it/s]
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
#  36%|███▌      | 36/100 [00:00<00:00, 77.08it/s]
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
#  44%|████▍     | 44/100 [00:00<00:00, 73.04it/s]
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
#  52%|█████▏    | 52/100 [00:00<00:00, 73.27it/s]
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
#  60%|██████    | 60/100 [00:00<00:00, 69.89it/s]
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
#  68%|██████▊   | 68/100 [00:00<00:00, 63.44it/s]
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
#  75%|███████▌  | 75/100 [00:01<00:00, 61.90it/s]
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
#  83%|████████▎ | 83/100 [00:01<00:00, 65.47it/s]
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
#  91%|█████████ | 91/100 [00:01<00:00, 68.24it/s]
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
#  99%|█████████▉| 99/100 [00:01<00:00, 70.24it/s]
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled 0.0
# nan
# nan
# sampled_gradient_x.shape=(76,)
# grad dF dla:  0.11352326852441053
# grad dF dmu:  0.11333220509687902
# sampled
# 100%|██████████| 100/100 [00:01<00:00, 69.97it/s]
#  12%|█▏        | 12/100 [00:14<01:47,  1.23s/it]
# 0.0
# nan
# nan
# z2.shape=(48,)
# y2.shape=(48,)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-18989ffbeb84> in <cell line: 1>()
# ----> 1 t_calls, la_mu_calls, history, dgap_log, la_mu_grad_norms, t_grad_norms, x1_list, x2_list, *l_ = test_transport_problem(graph, net_df, l, w, params, sources, targets)
#
# <ipython-input-6-2c6f06d3d6aa> in test_transport_problem(graph, net_df, l, w, params, sources, targets)
#       9         targets
#      10     )
# ---> 11     return ACRCD_star(oracle_stacker, *oracle_stacker.get_init_vars_block(), 100)
#
# /content/transport_network_optimization/acrcd.py in ACRCD_star(oracle_stacker, x1_0, x2_0, K, L1_init, L2_init)
#     126         x2 = tau * z2 + (1 - tau) * y2
#     127
# --> 128         *_x, res_x, flows = oracle_stacker.t_step(x1)  # moved out of the inner loop
#     129
#     130         n_ = L1 ** beta + L2 ** beta
#
# /content/transport_network_optimization/acrcd.py in t_step(self, t_block)
#      44         T, pred_maps = self.oracle.get_T_and_predmaps(self.graph, self.optim_params, self.sources, self.targets)
#      45         self.d = self.oracle.get_d(self.optim_params, T)
# ---> 46         grad_t = self.oracle.get_flows_on_shortest(self.sources, self.targets, self.d, pred_maps)
#      47         t_grad = np.hstack([grad_t])
#      48         log.t_grad_norms.append(np.linalg.norm(t_grad))
#
# /content/transport_network_optimization/transport_problem.py in get_flows_on_shortest(self, sources, targets, d, pred_maps)
#      99         for ind, source in enumerate(sources):
#     100             pred_map = pred_maps[ind]
# --> 101             self.sum_flows_from_tree(flows_on_shortest, source, targets, np.array(pred_map.a), d)
#     102         return flows_on_shortest
#     103
#
# /content/transport_network_optimization/transport_problem.py in sum_flows_from_tree(self, flows, source, targets, pred_map_arr, d)
#      60                 v_pred = pred_map_arr[v]
#      61                 # print(v, source, pred_map_arr)
# ---> 62                 flows[self.edge_to_ind[(v_pred, v)]] += corr
#      63                 v = v_pred
#      64         return flows
#
# /usr/local/lib/python3.10/dist-packages/numba/typed/typeddict.py in __getitem__(self, key)
#     148             raise KeyError(key)
#     149         else:
# --> 150             return _getitem(self, key)
#     151
#     152     def __setitem__(self, key, value):
#
# /usr/local/lib/python3.10/dist-packages/numba/typed/dictobject.py in impl()
#     758         ix, val = _dict_lookup(d, castedkey, hash(castedkey))
#     759         if ix == DKIX.EMPTY:
# --> 760             raise KeyError()
#     761         elif ix < DKIX.EMPTY:
#     762             raise AssertionError("internal dict error during lookup")
#
# KeyError:

# %%
plt.plot(la_mu_grad_norms, label='la mu grads')

# %%
plt.plot(dgap_log, label="dgap")

# %%
t_calls

# %%
la_mu_calls
